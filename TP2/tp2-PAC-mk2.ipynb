# %% [markdown]
# [Link a la carpeta con todo el TP](https://drive.google.com/drive/u/0/folders/1do-iyf2SzQln-fh8tmu9mSfzLuim5xs5)

# %% [markdown]
# # Imports & Download stage

# %%
# !pip install category_encoders
# Out:
# Requirement already satisfied: category_encoders in /usr/local/lib/python3.10/dist-packages (2.6.3)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.23.5)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.2.2)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.11.4)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (0.14.0)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.5.3)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (0.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category_encoders) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category_encoders) (2023.3.post1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->category_encoders) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->category_encoders) (3.2.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.9.0->category_encoders) (23.2)

# %%
from sklearn.linear_model import LogisticRegressionCV
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from category_encoders import TargetEncoder
from category_encoders import BinaryEncoder
import pandas as pd
import numpy as np
import math
# %matplotlib inline
import pyarrow.parquet as pq
import os
import random

from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV
from sklearn.linear_model import SGDClassifier
from scipy.stats import uniform, randint
from sklearn.metrics import f1_score

pd.options.display.float_format = '{:20,.10f}'.format

import gc

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
if not os.path.exists('test.parq'):
  id1="1puQpPyRVtoX_MTPJITQEtQny8a714zXk"
  downloaded1 = drive.CreateFile({'id': id1})
  downloaded1.GetContentFile('test.parq')

if not os.path.exists('train.parq'):
  id2="1Tf5pfrYBk8yM6QzC5IWebtSlja3R5BwN"
  downloaded2 = drive.CreateFile({'id': id2})
  downloaded2.GetContentFile('train.parq')

# %% [markdown]
# load dataframe

# %%
train_df = pq.read_table('train.parq').to_pandas()
test_df = pq.read_table('test.parq').to_pandas()

# %% [markdown]
# # Feature engineering stage

# %% [markdown]
# ### Feature engineering, 1,2/5: split attack type into service and class

# %%
train_df['attack_category'] = train_df['attack_type'].apply(lambda x: x.split(':')[1]).astype('category')
train_df['attack_service'] = train_df['attack_type'].apply(lambda x: x.split(':')[0]).astype('category')

test_df['attack_category'] = test_df['attack_type'].apply(lambda x: x.split(':')[1]).astype('category')
test_df['attack_service'] = test_df['attack_type'].apply(lambda x: x.split(':')[0]).astype('category')

# %% [markdown]
# ### Feature Engineering 3,4/5: encode time: hour as categorical and day sine-encoded

# %%
# Function to categorize the hour of day
def categorize_time(hour):
    if 7 <= hour < 12:
        return 'morning'
    elif 13 <= hour < 19:
        return 'afternoon'
    else:
        return 'night'

# Feature engineering for training set
train_df['attack_time_of_day'] = train_df['attack_time'].dt.hour.apply(categorize_time).astype("category")
test_df['attack_time_of_day'] = test_df['attack_time'].dt.hour.apply(categorize_time).astype("category")

# sine-encode day
train_df['attack_day_sin'] = train_df['attack_time'].dt.dayofweek.apply(lambda x: math.sin((2*x*np.pi)/7)).astype('float32')
train_df['attack_day_cos'] = train_df['attack_time'].dt.dayofweek.apply(lambda x: math.cos((2*x*np.pi)/7)).astype('float32')

test_df['attack_day_sin'] = test_df['attack_time'].dt.dayofweek.apply(lambda x: math.sin((2*x*np.pi)/7)).astype('float32')
test_df['attack_day_cos'] = test_df['attack_time'].dt.dayofweek.apply(lambda x: math.cos((2*x*np.pi)/7)).astype('float32')

# Deleting unused data to free up memory
train_df.drop('attack_time', axis=1, inplace=True)
test_df.drop('attack_time', axis=1, inplace=True)

gc.collect()
# Out:
# 48

# %% [markdown]
# ### Feature engineering 5/5: attacker/watcher continent

# %%
continents = {
    'US': 'NA', 'DE': 'EU', 'SG': 'AS', 'CN': 'AS', 'NL': 'EU', 'GI': 'EU',
    'FR': 'EU', 'IN': 'AS', 'GB': 'EU', 'RU': 'EU', 'CA': 'NA', 'GM': 'AF',
    'VN': 'AS', 'BR': 'SA', 'ID': 'AS', 'HK': 'AS', 'IT': 'EU', 'GN': 'AF',
    'AU': 'OC', 'JP': 'AS', 'KR': 'AS', 'UA': 'EU', 'SE': 'EU', 'GP': 'CA',
    'FI': 'EU', 'BG': 'EU', 'IR': 'AS', 'TR': 'AS', 'BD': 'AS', 'PH': 'AS',
    'ES': 'EU', 'SK': 'EU', 'TH': 'AS', 'PL': 'EU', 'AR': 'SA', 'GQ': 'AF',
    'LU': 'EU', 'CH': 'EU', 'PK': 'AS', 'MX': 'NA', 'RO': 'EU', 'GU': 'CA',
    'ZA': 'AF', 'BE': 'EU', 'NO': 'EU', 'RS': 'EU', 'TW': 'AS', 'GY': 'SA',
    'AT': 'EU', 'AE': 'AS', 'LV': 'EU', 'MY': 'AS', 'PT': 'EU', 'KM': 'AF',
    'CZ': 'EU', 'CO': 'SA', 'AZ': 'AS', 'DK': 'EU', 'LT': 'EU', 'LC': 'CA',
    'IL': 'AS', 'KH': 'AS', 'IE': 'EU', 'GR': 'EU', 'VE': 'SA', 'ML': 'AF',
    'PE': 'SA', 'SA': 'AS', 'KE': 'AF', 'CL': 'SA', 'BF': 'AF', 'MW': 'AF',
    'MA': 'AF', 'MD': 'EU', 'CI': 'AF', 'MN': 'AS', 'HR': 'EU', 'NA': 'AF',
    'KZ': 'AS', 'EG': 'AF', 'ET': 'AF', 'MC': 'EU', 'MU': 'AF', 'RE': 'AF',
    'TN': 'AF', 'DO': 'NA', 'NP': 'AS', 'PA': 'CA', 'BM': 'NA', 'SD': 'AF',
    'GH': 'AF', 'HU': 'EU', 'EE': 'EU', 'BY': 'EU', 'BA': 'EU', 'SX': 'CA',
    'DZ': 'AF', 'MK': 'EU', 'GE': 'AS', 'EC': 'SA', 'IQ': 'AS', 'TC': 'CA',
    'LK': 'AS', 'NG': 'AF', 'AM': 'EU', 'AL': 'EU', 'BW': 'AF', 'YE': 'AS',
    'LB': 'AS', 'AO': 'AF', 'NZ': 'OC', 'JO': 'AS', 'BO': 'SA', 'NC': 'OC',
    'TZ': 'AF', 'PY': 'SA', 'GT': 'CA', 'HN': 'CA', 'BN': 'AS', 'SM': 'EU',
    'MZ': 'AF', 'UZ': 'AS', 'QA': 'AS', 'CY': 'EU', 'LA': 'AS', 'SI': 'EU',
    'OM': 'AS', 'KW': 'AS', 'UG': 'AF', 'ME': 'EU', 'SV': 'CA', 'AS': 'NA',
    'JM': 'NA', 'BH': 'AS', 'UY': 'SA', 'BB': 'NA', 'BQ': 'SA', 'CC': 'OC',
    'RW': 'AF', 'PF': 'OC', 'CR': 'CA', 'MV': 'AS', 'PS': 'AS', 'CK': 'OC',
    'LY': 'AF', 'SN': 'AF', 'ZW': 'AF', 'TT': 'NA', 'XK': 'EU', 'FK': 'SA',
    'IS': 'EU', 'MT': 'EU', 'MM': 'AS', 'KG': 'AS', 'BI': 'AF', 'LI': 'EU',
    'WS': 'OC', 'BZ': 'CA', 'PR': 'NA', 'TG': 'AF', 'BS': 'NA', 'TF': 'SA',
    'NI': 'CA', 'SC': 'AF', 'ZM': 'AF', 'CM': 'AF', 'MR': 'AF',
    'VG': 'NA', 'CW': 'NA', 'SO': 'AF', 'MG': 'AF', 'DM': 'NA',
    'AF': 'AS', 'SY': 'AS', 'CD': 'AF', 'CV': 'AF', 'SS': 'AF', 'AG': 'NA',
    'SR': 'SA', 'TJ': 'AS', 'HT': 'NA', 'BJ': 'AF', 'AD': 'EU',
    'DJ': 'AF', 'IM': 'EU', 'MO': 'AS', 'GG': 'EU', 'GF': 'SA',
    'BT': 'AS', 'ER': 'AF', 'NE': 'AF', 'FO': 'EU', 'GD': 'NA',
    'SB': 'OC', 'SZ': 'AF', 'KN': 'NA', 'KY': 'NA', 'FM': 'OC',
    'LS': 'AF', 'VC': 'NA', 'CX': 'OC', 'GW': 'AF', 'PG': 'OC',
    'PM': 'NA', 'GL': 'NA', 'SH': 'AF', 'ST': 'AF', 'GA': 'AF',
    'VI': 'NA', 'LR': 'AF', 'TL': 'AS', 'CG': 'AF', 'MP': 'OC',
    'KP': 'AS', 'CU': 'CA', 'AI': 'NA', 'SL': 'AF', 'AW': 'NA',
    'FJ': 'OC', 'MQ': 'NA', 'JE': 'EU', 'GG': 'EU'
}

# %%
test_df['attacker_continent'] = test_df['attacker_country'].apply(lambda x: continents[x]).astype('category')
test_df['watcher_continent'] = test_df['watcher_country'].apply(lambda x: continents[x]).astype('category')

train_df['attacker_continent'] = train_df['attacker_country'].apply(lambda x: continents[x]).astype('category')
train_df['watcher_continent'] = train_df['watcher_country'].apply(lambda x: continents[x]).astype('category')

del continents
gc.collect()
# Out:
# 0

# %% [markdown]
# ### Ctrl+s

# %%
train_df.to_parquet("train_fe.pq")
test_df.to_parquet("test_fe.pq")

# %% [markdown]
# # Init stage

# %% [markdown]
# Load in case I don't have them

# %%
import pyarrow.parquet as pq
train_df = pq.read_table('train_fe.pq').to_pandas()
test_df = pq.read_table('test_fe.pq').to_pandas()

# %% [markdown]
# Train/test split based on IPs

# %%
# Create a DataFrame with unique IPs and their corresponding labels
raw_df = train_df
ip_label_df = raw_df[['attacker_ip_enum', 'label']].drop_duplicates()

# Split the unique IPs into two sets with roughly 80%-20% proportions, stratified by label
train_ips, test_ips = train_test_split(ip_label_df['attacker_ip_enum'],
                                       test_size=0.2,
                                       random_state=42,
                                       stratify=ip_label_df['label'])

# Use these sets to filter the original DataFrame
train_df = raw_df[raw_df['attacker_ip_enum'].isin(train_ips)]
val_df = raw_df[raw_df['attacker_ip_enum'].isin(test_ips)]

del raw_df
del ip_label_df
gc.collect()
# Out:
# 4

# %% [markdown]
# # Encoding stage

# %% [markdown]
# Para el encoding traté de mantener la mayor cantidad de información posible de los dataframes. Por eso sólo usé mean cuando había demasiadas categorías.
#
# Además, las categorías mean-encodeadas en el preceptron eran muy importantes, por lo que me pareció que beneficiaría al modelo tenerlas así
#
# Por como me quedó armado el dataset, no tuve que tener ninguna consideración especial por usar un modelo de árboles ya que las únicas columnas que no son un mean/OHE/binary son las del día que están encodeadas con sinoidales

# %% [markdown]
# ### Drop IP to avoid overfitting/target leak

# %%
train_df.drop(['attacker_ip_enum'], axis=1, inplace=True)
val_df.drop(['attacker_ip_enum'], axis=1, inplace=True)

test_ips = test_df['attacker_ip_enum'] # I'll need these for kaggle submission
test_df.drop(['attacker_ip_enum'], axis=1, inplace=True)

# %% [markdown]
# ### Countries (binary)

# %%
# Initialize a BinaryEncoder for the 'watcher_country' column
binary_encoder = BinaryEncoder(cols=['watcher_country'])

# Fit and transform on the training data
train_df_encoded = binary_encoder.fit_transform(train_df[['watcher_country']])

# Transform the test data
test_df_encoded = binary_encoder.transform(test_df[['watcher_country']])
val_df_encoded = binary_encoder.transform(val_df[['watcher_country']])

# Merge the encoded columns back into the original DataFrames
train_df = pd.concat([train_df, train_df_encoded], axis=1)
test_df = pd.concat([test_df, test_df_encoded], axis=1)
val_df = pd.concat([val_df, val_df_encoded], axis=1)

# Clean up unnecessary variables
del train_df_encoded, test_df_encoded, val_df_encoded
gc.collect()

# Drop the original 'watcher_country' column
train_df.drop('watcher_country', axis=1, inplace=True)
test_df.drop('watcher_country', axis=1, inplace=True)
val_df.drop('watcher_country', axis=1, inplace=True)

# Cast to uint8 for efficiency
train_df['watcher_country_0'] = train_df['watcher_country_0'].astype('uint8')
test_df['watcher_country_0'] = test_df['watcher_country_0'].astype('uint8')
val_df['watcher_country_0'] = val_df['watcher_country_0'].astype('uint8')

train_df['watcher_country_1'] = train_df['watcher_country_1'].astype('uint8')
test_df['watcher_country_1'] = test_df['watcher_country_1'].astype('uint8')
val_df['watcher_country_1'] = val_df['watcher_country_1'].astype('uint8')

train_df['watcher_country_2'] = train_df['watcher_country_2'].astype('uint8')
test_df['watcher_country_2'] = test_df['watcher_country_2'].astype('uint8')
val_df['watcher_country_2'] = val_df['watcher_country_2'].astype('uint8')

train_df['watcher_country_3'] = train_df['watcher_country_3'].astype('uint8')
test_df['watcher_country_3'] = test_df['watcher_country_3'].astype('uint8')
val_df['watcher_country_3'] = val_df['watcher_country_3'].astype('uint8')

train_df['watcher_country_4'] = train_df['watcher_country_4'].astype('uint8')
test_df['watcher_country_4'] = test_df['watcher_country_4'].astype('uint8')
val_df['watcher_country_4'] = val_df['watcher_country_4'].astype('uint8')

# %%
# Initialize a BinaryEncoder for the 'attacker_country' column
binary_encoder = BinaryEncoder(cols=['attacker_country'])

# Fit and transform on the training data
train_df_encoded = binary_encoder.fit_transform(train_df[['attacker_country']])

# Transform the test data
test_df_encoded = binary_encoder.transform(test_df[['attacker_country']])
val_df_encoded = binary_encoder.transform(val_df[['attacker_country']])

# Merge the encoded columns back into the original DataFrames
train_df = pd.concat([train_df, train_df_encoded], axis=1)
test_df = pd.concat([test_df, test_df_encoded], axis=1)
val_df = pd.concat([val_df, val_df_encoded], axis=1)

# Clean up unnecessary variables
del train_df_encoded, test_df_encoded, val_df_encoded
gc.collect()

# Drop the original 'attacker_country' column
train_df.drop('attacker_country', axis=1, inplace=True)
test_df.drop('attacker_country', axis=1, inplace=True)
val_df.drop('attacker_country', axis=1, inplace=True)

# Cast to uint8 for efficiency
train_df['attacker_country_0'] = train_df['attacker_country_0'].astype('uint8')
test_df['attacker_country_0'] = test_df['attacker_country_0'].astype('uint8')
val_df['attacker_country_0'] = val_df['attacker_country_0'].astype('uint8')

train_df['attacker_country_1'] = train_df['attacker_country_1'].astype('uint8')
test_df['attacker_country_1'] = test_df['attacker_country_1'].astype('uint8')
val_df['attacker_country_1'] = val_df['attacker_country_1'].astype('uint8')

train_df['attacker_country_2'] = train_df['attacker_country_2'].astype('uint8')
test_df['attacker_country_2'] = test_df['attacker_country_2'].astype('uint8')
val_df['attacker_country_2'] = val_df['attacker_country_2'].astype('uint8')

train_df['attacker_country_3'] = train_df['attacker_country_3'].astype('uint8')
test_df['attacker_country_3'] = test_df['attacker_country_3'].astype('uint8')
val_df['attacker_country_3'] = val_df['attacker_country_3'].astype('uint8')

train_df['attacker_country_4'] = train_df['attacker_country_4'].astype('uint8')
test_df['attacker_country_4'] = test_df['attacker_country_4'].astype('uint8')
val_df['attacker_country_4'] = val_df['attacker_country_4'].astype('uint8')

# %% [markdown]
# ### AS Names (Mean/Target)

# %%
target_encoder = TargetEncoder(cols=['watcher_as_name'])

train_df_encoded = target_encoder.fit_transform(train_df[['watcher_as_name']], train_df['label'])
test_df_encoded = target_encoder.transform(test_df[['watcher_as_name']])
val_df_encoded = target_encoder.transform(val_df[['watcher_as_name']])

train_df[['watcher_as_name']] = train_df_encoded.astype('float32')
test_df[['watcher_as_name']] = test_df_encoded.astype('float32')
val_df[['watcher_as_name']] = val_df_encoded.astype('float32')

del train_df_encoded, test_df_encoded, val_df_encoded, target_encoder
gc.collect()
# Out:
# 0

# %%
target_encoder = TargetEncoder(cols=['attacker_as_name'])

train_df_encoded = target_encoder.fit_transform(train_df[['attacker_as_name']], train_df['label'])
test_df_encoded = target_encoder.transform(test_df[['attacker_as_name']])
val_df_encoded = target_encoder.transform(val_df[['attacker_as_name']])

train_df[['attacker_as_name']] = train_df_encoded.astype('float32')
test_df[['attacker_as_name']] = test_df_encoded.astype('float32')
val_df[['attacker_as_name']] = val_df_encoded.astype('float32')

del train_df_encoded, test_df_encoded, val_df_encoded, target_encoder
gc.collect()
# Out:
# 0

# %% [markdown]
# ### Watcher UUID Enums (Mean/Target)

# %%
target_encoder = TargetEncoder(cols=['watcher_uuid_enum'])

train_df_encoded = target_encoder.fit_transform(train_df[['watcher_uuid_enum']], train_df['label'])
test_df_encoded = target_encoder.transform(test_df[['watcher_uuid_enum']])
val_df_encoded = target_encoder.transform(val_df[['watcher_uuid_enum']])

train_df[['watcher_uuid_enum']] = train_df_encoded.astype('float32')
test_df[['watcher_uuid_enum']] = test_df_encoded.astype('float32')
val_df[['watcher_uuid_enum']] = val_df_encoded.astype('float32')

del train_df_encoded, test_df_encoded, val_df_encoded, target_encoder
gc.collect()
# Out:
# 0

# %% [markdown]
# ### Attack type (OHE/Bin)

# %%
#Not sure if I want to use this yet

train_df.drop(['attack_type'], axis=1, inplace=True)
test_df.drop(['attack_type'], axis=1, inplace=True)
val_df.drop(['attack_type'], axis=1, inplace=True)

# %%
# Initialize a BinaryEncoder for the 'attack_service' column
binary_encoder = BinaryEncoder(cols=['attack_service'])

# Fit and transform on the training data
train_df_encoded = binary_encoder.fit_transform(train_df[['attack_service']])

# Transform the test data
test_df_encoded = binary_encoder.transform(test_df[['attack_service']])
val_df_encoded = binary_encoder.transform(val_df[['attack_service']])

# Merge the encoded columns back into the original DataFrames
train_df = pd.concat([train_df, train_df_encoded], axis=1)
test_df = pd.concat([test_df, test_df_encoded], axis=1)
val_df = pd.concat([val_df, val_df_encoded], axis=1)

# Clean up unnecessary variables
del train_df_encoded, test_df_encoded, val_df_encoded
gc.collect()

# Drop the original 'attack_service' column
train_df.drop('attack_service', axis=1, inplace=True)
test_df.drop('attack_service', axis=1, inplace=True)
val_df.drop('attack_service', axis=1, inplace=True)

# Cast to uint8 for efficiency
train_df['attack_service_0'] = train_df['attack_service_0'].astype('uint8')
test_df['attack_service_0'] = test_df['attack_service_0'].astype('uint8')
val_df['attack_service_0'] = val_df['attack_service_0'].astype('uint8')

train_df['attack_service_1'] = train_df['attack_service_1'].astype('uint8')
test_df['attack_service_1'] = test_df['attack_service_1'].astype('uint8')
val_df['attack_service_1'] = val_df['attack_service_1'].astype('uint8')

train_df['attack_service_2'] = train_df['attack_service_2'].astype('uint8')
test_df['attack_service_2'] = test_df['attack_service_2'].astype('uint8')
val_df['attack_service_2'] = val_df['attack_service_2'].astype('uint8')

train_df['attack_service_3'] = train_df['attack_service_3'].astype('uint8')
test_df['attack_service_3'] = test_df['attack_service_3'].astype('uint8')
val_df['attack_service_3'] = val_df['attack_service_3'].astype('uint8')

# %%
# Create a OneHotEncoder instance
encoder = OneHotEncoder(sparse=True, drop='first')  # Use sparse=True

# Fit and transform the 'attack_category' column in both train and test DataFrames
encoded_attack_category_train = encoder.fit_transform(train_df[['attack_category']]
                                                      )
# Convert the sparse matrices to dense arrays of integers
encoded_attack_category_train = encoded_attack_category_train.todense().astype('int8')

# Create DataFrames for the one-hot encoded 'attack_category' column
encoded_attack_category_train_df = pd.DataFrame(encoded_attack_category_train, columns=encoder.get_feature_names_out(['attack_category']))

# Concatenate the one-hot encoded 'attack_category' columns to the respective DataFrames
train_df = train_df.reset_index().drop(['index', 'attack_category'],axis=1).join(encoded_attack_category_train_df)

# Run GC to save memory
del encoded_attack_category_train, encoded_attack_category_train_df
gc.collect()

# Do it again for other 2 dataframes

encoded_attack_category_test = encoder.transform(test_df[['attack_category']])
encoded_attack_category_test = encoded_attack_category_test.todense().astype('int8')
encoded_attack_category_test_df = pd.DataFrame(encoded_attack_category_test, columns=encoder.get_feature_names_out(['attack_category']))
test_df = test_df.reset_index().drop(['index', 'attack_category'],axis=1).join(encoded_attack_category_test_df)
del encoded_attack_category_test, encoded_attack_category_test_df
gc.collect()

encoded_attack_category_val = encoder.transform(val_df[['attack_category']])
encoded_attack_category_val = encoded_attack_category_val.todense().astype('int8')
encoded_attack_category_val_df = pd.DataFrame(encoded_attack_category_val, columns=encoder.get_feature_names_out(['attack_category']))
val_df = val_df.reset_index().drop(['index', 'attack_category'],axis=1).join(encoded_attack_category_val_df)
del encoded_attack_category_val, encoded_attack_category_val_df
gc.collect()

# %% [markdown]
# ### Attack time of day (OHE)

# %%
# Create a OneHotEncoder instance
encoder = OneHotEncoder(sparse=True, drop='first')  # Use sparse=True

# Fit and transform the 'attack_time_of_day' column in both train and test DataFrames
encoded_attack_time_of_day_train = encoder.fit_transform(train_df[['attack_time_of_day']]
                                                      )
# Convert the sparse matrices to dense arrays of integers
encoded_attack_time_of_day_train = encoded_attack_time_of_day_train.todense().astype('int8')

# Create DataFrames for the one-hot encoded 'attack_time_of_day' column
encoded_attack_time_of_day_train_df = pd.DataFrame(encoded_attack_time_of_day_train, columns=encoder.get_feature_names_out(['attack_time_of_day']))

# Concatenate the one-hot encoded 'attack_time_of_day' columns to the respective DataFrames
train_df = train_df.reset_index().drop(['index', 'attack_time_of_day'],axis=1).join(encoded_attack_time_of_day_train_df)

# Run GC to save memory
del encoded_attack_time_of_day_train, encoded_attack_time_of_day_train_df
gc.collect()

# Do it again for other 2 dataframes

encoded_attack_time_of_day_test = encoder.transform(test_df[['attack_time_of_day']])
encoded_attack_time_of_day_test = encoded_attack_time_of_day_test.todense().astype('int8')
encoded_attack_time_of_day_test_df = pd.DataFrame(encoded_attack_time_of_day_test, columns=encoder.get_feature_names_out(['attack_time_of_day']))
test_df = test_df.reset_index().drop(['index', 'attack_time_of_day'],axis=1).join(encoded_attack_time_of_day_test_df)
del encoded_attack_time_of_day_test, encoded_attack_time_of_day_test_df
gc.collect()

encoded_attack_time_of_day_val = encoder.transform(val_df[['attack_time_of_day']])
encoded_attack_time_of_day_val = encoded_attack_time_of_day_val.todense().astype('int8')
encoded_attack_time_of_day_val_df = pd.DataFrame(encoded_attack_time_of_day_val, columns=encoder.get_feature_names_out(['attack_time_of_day']))
val_df = val_df.reset_index().drop(['index', 'attack_time_of_day'],axis=1).join(encoded_attack_time_of_day_val_df)
del encoded_attack_time_of_day_val, encoded_attack_time_of_day_val_df
gc.collect()

# %% [markdown]
# ### Continents (OHE)

# %%
# Create a OneHotEncoder instance
encoder = OneHotEncoder(sparse=True, drop='first')  # Use sparse=True

# Fit and transform the 'attacker_continent' column in both train and test DataFrames
encoded_attacker_continent_train = encoder.fit_transform(train_df[['attacker_continent']]
                                                      )
# Convert the sparse matrices to dense arrays of integers
encoded_attacker_continent_train = encoded_attacker_continent_train.todense().astype('int8')

# Create DataFrames for the one-hot encoded 'attacker_continent' column
encoded_attacker_continent_train_df = pd.DataFrame(encoded_attacker_continent_train, columns=encoder.get_feature_names_out(['attacker_continent']))

# Concatenate the one-hot encoded 'attacker_continent' columns to the respective DataFrames
train_df = train_df.reset_index().drop(['index', 'attacker_continent'],axis=1).join(encoded_attacker_continent_train_df)

# Run GC to save memory
del encoded_attacker_continent_train, encoded_attacker_continent_train_df
gc.collect()

# Do it again for other 2 dataframes

encoded_attacker_continent_test = encoder.transform(test_df[['attacker_continent']])
encoded_attacker_continent_test = encoded_attacker_continent_test.todense().astype('int8')
encoded_attacker_continent_test_df = pd.DataFrame(encoded_attacker_continent_test, columns=encoder.get_feature_names_out(['attacker_continent']))
test_df = test_df.reset_index().drop(['index', 'attacker_continent'],axis=1).join(encoded_attacker_continent_test_df)
del encoded_attacker_continent_test, encoded_attacker_continent_test_df
gc.collect()

encoded_attacker_continent_val = encoder.transform(val_df[['attacker_continent']])
encoded_attacker_continent_val = encoded_attacker_continent_val.todense().astype('int8')
encoded_attacker_continent_val_df = pd.DataFrame(encoded_attacker_continent_val, columns=encoder.get_feature_names_out(['attacker_continent']))
val_df = val_df.reset_index().drop(['index', 'attacker_continent'],axis=1).join(encoded_attacker_continent_val_df)
del encoded_attacker_continent_val, encoded_attacker_continent_val_df
gc.collect()

# %%
# Create a OneHotEncoder instance
encoder = OneHotEncoder(sparse=True, drop='first')  # Use sparse=True

# Fit and transform the 'watcher_continent' column in both train and test DataFrames
encoded_watcher_continent_train = encoder.fit_transform(train_df[['watcher_continent']]
                                                      )
# Convert the sparse matrices to dense arrays of integers
encoded_watcher_continent_train = encoded_watcher_continent_train.todense().astype('int8')

# Create DataFrames for the one-hot encoded 'watcher_continent' column
encoded_watcher_continent_train_df = pd.DataFrame(encoded_watcher_continent_train, columns=encoder.get_feature_names_out(['watcher_continent']))

# Concatenate the one-hot encoded 'watcher_continent' columns to the respective DataFrames
train_df = train_df.reset_index().drop(['index', 'watcher_continent'],axis=1).join(encoded_watcher_continent_train_df)

# Run GC to save memory
del encoded_watcher_continent_train, encoded_watcher_continent_train_df
gc.collect()

# Do it again for other 2 dataframes

encoded_watcher_continent_test = encoder.transform(test_df[['watcher_continent']])
encoded_watcher_continent_test = encoded_watcher_continent_test.todense().astype('int8')
encoded_watcher_continent_test_df = pd.DataFrame(encoded_watcher_continent_test, columns=encoder.get_feature_names_out(['watcher_continent']))
test_df = test_df.reset_index().drop(['index', 'watcher_continent'],axis=1).join(encoded_watcher_continent_test_df)
del encoded_watcher_continent_test, encoded_watcher_continent_test_df
gc.collect()

encoded_watcher_continent_val = encoder.transform(val_df[['watcher_continent']])
encoded_watcher_continent_val = encoded_watcher_continent_val.todense().astype('int8')
encoded_watcher_continent_val_df = pd.DataFrame(encoded_watcher_continent_val, columns=encoder.get_feature_names_out(['watcher_continent']))
val_df = val_df.reset_index().drop(['index', 'watcher_continent'],axis=1).join(encoded_watcher_continent_val_df)
del encoded_watcher_continent_val, encoded_watcher_continent_val_df
gc.collect()

# %% [markdown]
# ### Checkpoint!

# %%
train_df.sample(5)

# %% [markdown]
# # Model Stage

# %%
# I need all memory I can get
test_df.to_parquet('test_processed.parq')
del test_df
gc.collect()

# %% [markdown]
# ### Hiperparam search

# %% [markdown]
# Metodología de la búsqueda: me guardé el score para los defaults (lo único que cambié para la 'base' fue el `n_estimators`=10), y luego puse rangos que me parecieron aceptables alrededor de esos parámetros.
#
# Luego lo dejé corriendo y que me devolviera todos las combinaciones que superaran esa base, y repetir eso para varias combinaciones de los parámetros más 'categóricos'.
#
# El problema de hacer este tipo de cosas con random forest es que tarda *mucho más* que SGD en entrenar (~15 minutos por fit vs. ~30 segundos), por lo que no podía probar muchas combinaciones. Este problema se ve claro en los rangos de `n_estimators`: números más altos podrían darme mejores resultados, pero el tiempo que tardaría en fitear crecería de más (con el default de 100 tarda más de una hora)

# %%
train0_df = train_df[train_df.label == 0]
train1_df = train_df[train_df.label == 1]

# %%
from sklearn.linear_model import PassiveAggressiveClassifier

# Define hyperparameters
n_batches = 6 # ~?M batch size
n_max_iter = 10000
cut_score = 0.48

# Split the data into features (X) and target variable (y)
X_train = train_df.drop('label', axis=1)
y_train = train_df['label']

X_batch_size = int(np.floor(X_train.shape[0]/n_batches))
y_batch_size = int(np.floor(y_train.shape[0]/n_batches))

X_test = val_df.drop('label', axis=1)
y_test = val_df['label']

penalty_opt = ['l1', 'l2', 'elasticnet']
for n_iter in range(n_max_iter):

  params = {
        'C': random.uniform(0.3, 1.0),
        'max_iter': random.randint(1000, 10000),
        'tol': (random.uniform(10e-10, 10))*(10**(-1*random.randint(2,5))),
        'n_iter_no_change': random.randint(5, 15),
        'shuffle': False, # Va MUCHO mejor que true
        'loss': 'squared_hinge' # Va mejor que hinge
        }

  # Instantiate the model
  model = PassiveAggressiveClassifier(
                C=params['C'],
                max_iter=params['max_iter'],
                tol=params['tol'],
                n_iter_no_change=params['n_iter_no_change'],
                shuffle=params['shuffle'],
                loss=params['loss'],
                random_state=42
                )

  # Train the model in batches, keeping label proportion
  for i in range(0, n_batches):
      X_batch = X_train.iloc[i*X_batch_size: (i+1)*X_batch_size]
      gc.collect()

      y_batch = y_train.iloc[i*y_batch_size:i*y_batch_size + y_batch_size]

      model.partial_fit(X_batch, y_batch, classes=[0,1])

  # Make predictions on the test set
  y_pred = model.predict(X_test)

  # Evaluate the model
  f1_accuracy = f1_score(y_test, y_pred)

  if f1_accuracy > cut_score:
    max_score = f1_accuracy
    print(f'F1 Accuracy: {f1_accuracy}')
    print(f'Best Params: {params}')
# Out:
# F1 Accuracy: 0.4968466743265671
# Best Params: {'C': 0.7224302804776632, 'max_iter': 7997, 'tol': 0.0007947787572787601, 'n_iter_no_change': 7, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5003645674364975
# Best Params: {'C': 0.5556407531322847, 'max_iter': 1087, 'tol': 0.002119759349945546, 'n_iter_no_change': 7, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49880063343536796
# Best Params: {'C': 0.6373848772119706, 'max_iter': 3878, 'tol': 0.004772078636473666, 'n_iter_no_change': 6, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4937803618232888
# Best Params: {'C': 0.8445998446157337, 'max_iter': 1414, 'tol': 0.05860853770160484, 'n_iter_no_change': 14, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5047416426179091
# Best Params: {'C': 0.32446347324947533, 'max_iter': 7129, 'tol': 0.00037569430947009905, 'n_iter_no_change': 9, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5006547192758677
# Best Params: {'C': 0.5393443739095769, 'max_iter': 4019, 'tol': 0.0002906765448556252, 'n_iter_no_change': 14, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4992446488890398
# Best Params: {'C': 0.6093005669728466, 'max_iter': 2461, 'tol': 1.5133810084953557e-05, 'n_iter_no_change': 12, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4923409638760193
# Best Params: {'C': 0.9066083133089966, 'max_iter': 6549, 'tol': 0.031224465507302165, 'n_iter_no_change': 11, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.491854309732924
# Best Params: {'C': 0.9314527756679891, 'max_iter': 4984, 'tol': 0.0031260301623780655, 'n_iter_no_change': 11, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4988282444044425
# Best Params: {'C': 0.6327959400318782, 'max_iter': 8764, 'tol': 2.959632759949711e-05, 'n_iter_no_change': 5, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5042027433755153
# Best Params: {'C': 0.3462702411822627, 'max_iter': 3174, 'tol': 5.708720957328617e-05, 'n_iter_no_change': 13, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5054225186083324
# Best Params: {'C': 0.30759506294914596, 'max_iter': 5584, 'tol': 0.04304536289345427, 'n_iter_no_change': 9, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5012214070100719
# Best Params: {'C': 0.5007066368240357, 'max_iter': 3708, 'tol': 0.03401297729892269, 'n_iter_no_change': 9, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5022445787716109
# Best Params: {'C': 0.4546391013039497, 'max_iter': 7650, 'tol': 0.0008971283135425835, 'n_iter_no_change': 11, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49695804225555845
# Best Params: {'C': 0.7084363012598595, 'max_iter': 5803, 'tol': 2.0005959119219778e-05, 'n_iter_no_change': 5, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5007859336934647
# Best Params: {'C': 0.5315865040816444, 'max_iter': 3726, 'tol': 0.0019485101320913655, 'n_iter_no_change': 6, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5023309678482821
# Best Params: {'C': 0.4465398240484738, 'max_iter': 3166, 'tol': 0.054205845482160266, 'n_iter_no_change': 8, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.491106157012593
# Best Params: {'C': 0.9688818084574222, 'max_iter': 9241, 'tol': 6.88692529637971e-05, 'n_iter_no_change': 11, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5044126943987861
# Best Params: {'C': 0.336286322076138, 'max_iter': 5950, 'tol': 3.9658417444274195e-05, 'n_iter_no_change': 6, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4910306225501104
# Best Params: {'C': 0.9751314620188445, 'max_iter': 5819, 'tol': 0.04171059453569354, 'n_iter_no_change': 11, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5007457753521246
# Best Params: {'C': 0.5360388065430495, 'max_iter': 5194, 'tol': 0.0033168206171384166, 'n_iter_no_change': 7, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4977021609465142
# Best Params: {'C': 0.6780845623864573, 'max_iter': 1839, 'tol': 0.0006930861576881411, 'n_iter_no_change': 10, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5002374128779528
# Best Params: {'C': 0.5600215280624543, 'max_iter': 8994, 'tol': 0.000985433049653367, 'n_iter_no_change': 6, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5000551225841469
# Best Params: {'C': 0.5664228357031933, 'max_iter': 2022, 'tol': 0.015574768422063678, 'n_iter_no_change': 15, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49356593317450964
# Best Params: {'C': 0.8544936919684534, 'max_iter': 2255, 'tol': 5.493982115148216e-06, 'n_iter_no_change': 10, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.500642022604281
# Best Params: {'C': 0.5406118015720085, 'max_iter': 7071, 'tol': 1.7211492032118243e-05, 'n_iter_no_change': 14, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4955321569646791
# Best Params: {'C': 0.7686050382949514, 'max_iter': 8123, 'tol': 0.0010084090517803563, 'n_iter_no_change': 14, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49094861896895564
# Best Params: {'C': 0.9798341117588376, 'max_iter': 8178, 'tol': 0.0821014623252123, 'n_iter_no_change': 10, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.494032099070996
# Best Params: {'C': 0.8305059114315356, 'max_iter': 6752, 'tol': 0.0006989327924743254, 'n_iter_no_change': 11, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4982599569132188
# Best Params: {'C': 0.6637501522432059, 'max_iter': 2525, 'tol': 0.03119581293669235, 'n_iter_no_change': 6, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4945105566218809
# Best Params: {'C': 0.8097048880455531, 'max_iter': 5308, 'tol': 0.004860635762075419, 'n_iter_no_change': 5, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49417376723229406
# Best Params: {'C': 0.8234515766742911, 'max_iter': 8625, 'tol': 0.0031272650585956584, 'n_iter_no_change': 13, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5029942142826976
# Best Params: {'C': 0.4029814628818783, 'max_iter': 4307, 'tol': 0.0021997232105770365, 'n_iter_no_change': 12, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5039366094132828
# Best Params: {'C': 0.3602195064378637, 'max_iter': 5627, 'tol': 3.493217503749556e-06, 'n_iter_no_change': 14, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.503872960156606
# Best Params: {'C': 0.37143451697045976, 'max_iter': 5301, 'tol': 0.003954575486036644, 'n_iter_no_change': 6, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49590444994398697
# Best Params: {'C': 0.753267608697307, 'max_iter': 7144, 'tol': 0.09242071923845911, 'n_iter_no_change': 11, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5009783243971235
# Best Params: {'C': 0.5145184541664769, 'max_iter': 7608, 'tol': 0.0006648745631074071, 'n_iter_no_change': 14, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5055378980824686
# Best Params: {'C': 0.30537785758146074, 'max_iter': 7534, 'tol': 0.053921281172816374, 'n_iter_no_change': 10, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49363024693466306
# Best Params: {'C': 0.8527364333628218, 'max_iter': 4360, 'tol': 0.0006167579209676052, 'n_iter_no_change': 13, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4921169630642955
# Best Params: {'C': 0.917129041636616, 'max_iter': 6777, 'tol': 7.793901045919558e-05, 'n_iter_no_change': 15, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49237331236296966
# Best Params: {'C': 0.9042798238085517, 'max_iter': 8002, 'tol': 0.0396437482649636, 'n_iter_no_change': 9, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5030552564346192
# Best Params: {'C': 0.40084469094913294, 'max_iter': 7803, 'tol': 0.007375375229468659, 'n_iter_no_change': 7, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4916853432789859
# Best Params: {'C': 0.9423212568401145, 'max_iter': 5461, 'tol': 0.07494086964619713, 'n_iter_no_change': 6, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5007859336934647
# Best Params: {'C': 0.5323251800321963, 'max_iter': 9528, 'tol': 0.016640097946759917, 'n_iter_no_change': 13, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5007605513255625
# Best Params: {'C': 0.5344420734921902, 'max_iter': 1755, 'tol': 0.009673147784952194, 'n_iter_no_change': 6, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4905262977644974
# Best Params: {'C': 0.9993163661600344, 'max_iter': 4852, 'tol': 0.07813526843864363, 'n_iter_no_change': 6, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5009296553710363
# Best Params: {'C': 0.5161257731151531, 'max_iter': 2586, 'tol': 0.005936100289551016, 'n_iter_no_change': 10, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4950050951014543
# Best Params: {'C': 0.7916582193437864, 'max_iter': 5055, 'tol': 0.008663864460282318, 'n_iter_no_change': 15, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5017743770646432
# Best Params: {'C': 0.47649790582850116, 'max_iter': 9837, 'tol': 0.005898659747650448, 'n_iter_no_change': 7, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4944543980889003
# Best Params: {'C': 0.8139934506474007, 'max_iter': 7538, 'tol': 0.0433132452870196, 'n_iter_no_change': 10, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4921905055012695
# Best Params: {'C': 0.9126028368920125, 'max_iter': 9138, 'tol': 0.00045737689043014705, 'n_iter_no_change': 7, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4992786217431893
# Best Params: {'C': 0.607279320793819, 'max_iter': 4290, 'tol': 2.4679431489102564e-05, 'n_iter_no_change': 15, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4942102074426781
# Best Params: {'C': 0.8218254568471322, 'max_iter': 8801, 'tol': 0.0008455104532050461, 'n_iter_no_change': 14, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4938125098713838
# Best Params: {'C': 0.8436639168257867, 'max_iter': 9014, 'tol': 4.580693398658173e-06, 'n_iter_no_change': 14, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5040562648631327
# Best Params: {'C': 0.3532257920742375, 'max_iter': 1198, 'tol': 7.809298758875459e-05, 'n_iter_no_change': 10, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4997518631472236
# Best Params: {'C': 0.5852181014583929, 'max_iter': 7905, 'tol': 0.007530383685349341, 'n_iter_no_change': 13, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4981918776850935
# Best Params: {'C': 0.665503204165176, 'max_iter': 3148, 'tol': 0.012552556053320492, 'n_iter_no_change': 14, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5048674560749474
# Best Params: {'C': 0.3211042653157746, 'max_iter': 6722, 'tol': 0.007188185820000631, 'n_iter_no_change': 5, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4925150532258134
# Best Params: {'C': 0.8978275011226384, 'max_iter': 1628, 'tol': 4.208615258386175e-05, 'n_iter_no_change': 9, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49442870793802474
# Best Params: {'C': 0.8147643026727573, 'max_iter': 4015, 'tol': 0.0003358391929467277, 'n_iter_no_change': 12, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5040751875260892
# Best Params: {'C': 0.35281941188434784, 'max_iter': 8043, 'tol': 0.07851550956294409, 'n_iter_no_change': 5, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4965348726331563
# Best Params: {'C': 0.7328098867470012, 'max_iter': 4154, 'tol': 7.33070971838838e-05, 'n_iter_no_change': 8, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5026509342695039
# Best Params: {'C': 0.4208353659595292, 'max_iter': 3083, 'tol': 0.0004153373710630482, 'n_iter_no_change': 11, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4969194111139477
# Best Params: {'C': 0.7145464288214676, 'max_iter': 7123, 'tol': 0.0008043897775046697, 'n_iter_no_change': 15, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5056526899733149
# Best Params: {'C': 0.3016713887816127, 'max_iter': 7114, 'tol': 0.029807249220367305, 'n_iter_no_change': 12, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49493019963671403
# Best Params: {'C': 0.7959586335776108, 'max_iter': 5922, 'tol': 7.1396990397567e-06, 'n_iter_no_change': 7, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.493984798760685
# Best Params: {'C': 0.8318405626879437, 'max_iter': 2774, 'tol': 0.00013201990715388278, 'n_iter_no_change': 10, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5006801337384472
# Best Params: {'C': 0.5380882531359699, 'max_iter': 4791, 'tol': 2.868078821426741e-06, 'n_iter_no_change': 11, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49970307277262166
# Best Params: {'C': 0.5879569134817084, 'max_iter': 4566, 'tol': 0.0011441098472585963, 'n_iter_no_change': 7, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4969087342617768
# Best Params: {'C': 0.7164525284872055, 'max_iter': 9150, 'tol': 0.02437960347130809, 'n_iter_no_change': 10, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4999872783248098
# Best Params: {'C': 0.5701137852128169, 'max_iter': 7657, 'tol': 0.0008694746069486643, 'n_iter_no_change': 10, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5008282038355794
# Best Params: {'C': 0.5274324459371955, 'max_iter': 4396, 'tol': 0.030277564963573554, 'n_iter_no_change': 8, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4944612930332152
# Best Params: {'C': 0.8116443689613722, 'max_iter': 5530, 'tol': 0.0033004841142979364, 'n_iter_no_change': 14, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49178014232927325
# Best Params: {'C': 0.9392059407282889, 'max_iter': 4273, 'tol': 0.004208187898528789, 'n_iter_no_change': 12, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49911725261853435
# Best Params: {'C': 0.6146188253877458, 'max_iter': 4846, 'tol': 6.391174146208102e-05, 'n_iter_no_change': 12, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5017704318838495
# Best Params: {'C': 0.47812833885083394, 'max_iter': 7717, 'tol': 0.007084156437304105, 'n_iter_no_change': 11, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.501831222986289
# Best Params: {'C': 0.4722460925755326, 'max_iter': 5331, 'tol': 0.008380536433539561, 'n_iter_no_change': 8, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4939159976611482
# Best Params: {'C': 0.837689773136032, 'max_iter': 4689, 'tol': 3.7708244222193804e-05, 'n_iter_no_change': 15, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49097896232390154
# Best Params: {'C': 0.9780892385594848, 'max_iter': 7838, 'tol': 0.0009667705483877805, 'n_iter_no_change': 15, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5004874327130929
# Best Params: {'C': 0.5493155747191372, 'max_iter': 7458, 'tol': 0.07705279681588528, 'n_iter_no_change': 11, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4982174044218569
# Best Params: {'C': 0.6651213300036583, 'max_iter': 7451, 'tol': 0.000523011767273567, 'n_iter_no_change': 5, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4957034095798842
# Best Params: {'C': 0.7613747851015267, 'max_iter': 4205, 'tol': 0.07346173857541721, 'n_iter_no_change': 9, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4988112422518468
# Best Params: {'C': 0.6365443114819285, 'max_iter': 6049, 'tol': 0.00010721554083808525, 'n_iter_no_change': 6, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5025434756891044
# Best Params: {'C': 0.43123588397139984, 'max_iter': 1832, 'tol': 0.007895762544509239, 'n_iter_no_change': 14, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5010333378506572
# Best Params: {'C': 0.5117808883731205, 'max_iter': 6491, 'tol': 9.293208812561611e-05, 'n_iter_no_change': 13, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5007859336934647
# Best Params: {'C': 0.531755491932614, 'max_iter': 5764, 'tol': 4.35061556867256e-05, 'n_iter_no_change': 15, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49625513614783584
# Best Params: {'C': 0.7417878327496594, 'max_iter': 1609, 'tol': 0.0030150134852627913, 'n_iter_no_change': 11, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4988282444044425
# Best Params: {'C': 0.6331661738489576, 'max_iter': 2585, 'tol': 9.699202815249324e-05, 'n_iter_no_change': 9, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4955364561805701
# Best Params: {'C': 0.7681434594019101, 'max_iter': 7233, 'tol': 0.011245685906780932, 'n_iter_no_change': 10, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4928547931628167
# Best Params: {'C': 0.8829896088331732, 'max_iter': 7184, 'tol': 3.2538431755944276e-05, 'n_iter_no_change': 6, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5023541643773087
# Best Params: {'C': 0.44614120652770073, 'max_iter': 4021, 'tol': 0.06169540890605441, 'n_iter_no_change': 8, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5023837297763352
# Best Params: {'C': 0.44376021209612154, 'max_iter': 8252, 'tol': 0.0004155628073062728, 'n_iter_no_change': 7, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5037490875180914
# Best Params: {'C': 0.3787933731258289, 'max_iter': 5875, 'tol': 0.021212507869749615, 'n_iter_no_change': 6, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5012700455523005
# Best Params: {'C': 0.4987571873190807, 'max_iter': 2022, 'tol': 0.06480234620562983, 'n_iter_no_change': 13, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49498584439062654
# Best Params: {'C': 0.7933711443622269, 'max_iter': 3740, 'tol': 7.885404943286355e-05, 'n_iter_no_change': 10, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5055565845526949
# Best Params: {'C': 0.30416957059818506, 'max_iter': 2472, 'tol': 0.007323721236745815, 'n_iter_no_change': 7, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49537609205199246
# Best Params: {'C': 0.7736893589788021, 'max_iter': 3752, 'tol': 0.0019589604657687296, 'n_iter_no_change': 6, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.504536241472161
# Best Params: {'C': 0.3296655840631909, 'max_iter': 1963, 'tol': 0.0005471825477678984, 'n_iter_no_change': 10, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5052194528312215
# Best Params: {'C': 0.3125188200978531, 'max_iter': 4740, 'tol': 0.062026205498461655, 'n_iter_no_change': 9, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5010480316060926
# Best Params: {'C': 0.50967737691285, 'max_iter': 9770, 'tol': 0.0007909553952041922, 'n_iter_no_change': 14, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49179949278740265
# Best Params: {'C': 0.9380760725240207, 'max_iter': 6546, 'tol': 0.000856323552723039, 'n_iter_no_change': 9, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4956711432272139
# Best Params: {'C': 0.7636748319034676, 'max_iter': 5040, 'tol': 0.0005458536526615896, 'n_iter_no_change': 8, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5001483943728854
# Best Params: {'C': 0.5614998285316786, 'max_iter': 4324, 'tol': 0.002992881543231957, 'n_iter_no_change': 12, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49288054785391133
# Best Params: {'C': 0.881562150879297, 'max_iter': 8562, 'tol': 0.0006845993313878815, 'n_iter_no_change': 5, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4972162795544347
# Best Params: {'C': 0.698575467208517, 'max_iter': 4667, 'tol': 0.0004658208650725255, 'n_iter_no_change': 12, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49297934599201176
# Best Params: {'C': 0.8793166238428467, 'max_iter': 5842, 'tol': 6.964543090284868e-06, 'n_iter_no_change': 11, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4991809609492366
# Best Params: {'C': 0.6117928014901254, 'max_iter': 7117, 'tol': 8.09555775498321e-05, 'n_iter_no_change': 8, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49311464206389877
# Best Params: {'C': 0.8720100789924268, 'max_iter': 8232, 'tol': 0.035360316791477414, 'n_iter_no_change': 10, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5048674560749474
# Best Params: {'C': 0.3212980011479916, 'max_iter': 7985, 'tol': 3.0851834611673006e-05, 'n_iter_no_change': 6, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5022509098748368
# Best Params: {'C': 0.45396717914453294, 'max_iter': 1641, 'tol': 0.000899644799468228, 'n_iter_no_change': 6, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49484878980674435
# Best Params: {'C': 0.7991670590119835, 'max_iter': 1285, 'tol': 0.0855435970930605, 'n_iter_no_change': 15, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5037448363453773
# Best Params: {'C': 0.3791403097662279, 'max_iter': 7495, 'tol': 0.004602694578988428, 'n_iter_no_change': 10, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5038084232368646
# Best Params: {'C': 0.3646992099188001, 'max_iter': 9245, 'tol': 0.006670434171495832, 'n_iter_no_change': 15, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4998409500583183
# Best Params: {'C': 0.5782730677744937, 'max_iter': 9012, 'tol': 0.0001467514208226636, 'n_iter_no_change': 8, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5038663871111992
# Best Params: {'C': 0.36893764866754103, 'max_iter': 5522, 'tol': 8.41009337124079e-05, 'n_iter_no_change': 15, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5028344048594624
# Best Params: {'C': 0.41237756420860633, 'max_iter': 3077, 'tol': 0.0004970607954775369, 'n_iter_no_change': 10, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4906102984927677
# Best Params: {'C': 0.9970368334172963, 'max_iter': 8594, 'tol': 2.1443126608144922e-05, 'n_iter_no_change': 14, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49448697988867324
# Best Params: {'C': 0.8108907585113969, 'max_iter': 2234, 'tol': 8.86491821626829e-06, 'n_iter_no_change': 10, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5003899825355647
# Best Params: {'C': 0.5534912666934908, 'max_iter': 3855, 'tol': 0.03420369012985709, 'n_iter_no_change': 15, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4905198357827503
# Best Params: {'C': 0.9998167844181292, 'max_iter': 5952, 'tol': 0.05121409922909329, 'n_iter_no_change': 11, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5028344048594624
# Best Params: {'C': 0.4121743290301997, 'max_iter': 4453, 'tol': 0.07664105432325587, 'n_iter_no_change': 12, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49499867825256466
# Best Params: {'C': 0.7925729728108994, 'max_iter': 6288, 'tol': 0.042695160186575605, 'n_iter_no_change': 6, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49486162636987757
# Best Params: {'C': 0.7986723155212498, 'max_iter': 2563, 'tol': 0.0009830192520804617, 'n_iter_no_change': 8, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49203078238563486
# Best Params: {'C': 0.924050200186461, 'max_iter': 1989, 'tol': 3.3597668884333925e-05, 'n_iter_no_change': 8, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4931403871452735
# Best Params: {'C': 0.8712410296906115, 'max_iter': 8867, 'tol': 0.05429934226393098, 'n_iter_no_change': 14, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5023246377791678
# Best Params: {'C': 0.4474905615250802, 'max_iter': 8007, 'tol': 0.0046517052321814415, 'n_iter_no_change': 6, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4969344208587026
# Best Params: {'C': 0.7117148994595652, 'max_iter': 5488, 'tol': 0.00014062106922512683, 'n_iter_no_change': 10, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5019831369929048
# Best Params: {'C': 0.4659217280923738, 'max_iter': 8619, 'tol': 0.06436081088680855, 'n_iter_no_change': 6, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5019346163116699
# Best Params: {'C': 0.46770117805604206, 'max_iter': 3928, 'tol': 0.0009799366324675218, 'n_iter_no_change': 14, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49156921286988964
# Best Params: {'C': 0.9484824729787529, 'max_iter': 9259, 'tol': 0.009619645863709968, 'n_iter_no_change': 7, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5040142353556308
# Best Params: {'C': 0.35650611722381265, 'max_iter': 2220, 'tol': 0.09442262942172573, 'n_iter_no_change': 5, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5021643557659791
# Best Params: {'C': 0.4582969268679627, 'max_iter': 8526, 'tol': 0.09255744854399385, 'n_iter_no_change': 11, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49323692336603475
# Best Params: {'C': 0.8692591077807668, 'max_iter': 6574, 'tol': 0.041025110859618075, 'n_iter_no_change': 11, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5043349982086786
# Best Params: {'C': 0.3410638475403316, 'max_iter': 7337, 'tol': 0.00018442058050577477, 'n_iter_no_change': 15, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5008112997318261
# Best Params: {'C': 0.5282326125656025, 'max_iter': 5926, 'tol': 0.0008616129506272371, 'n_iter_no_change': 8, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49689583714527646
# Best Params: {'C': 0.7178747473807513, 'max_iter': 3317, 'tol': 0.000642625589148282, 'n_iter_no_change': 8, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.494143750133339
# Best Params: {'C': 0.8254713842379298, 'max_iter': 5218, 'tol': 0.0003151798441841657, 'n_iter_no_change': 14, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5037258956074095
# Best Params: {'C': 0.3795733725188356, 'max_iter': 5899, 'tol': 0.047695237716286504, 'n_iter_no_change': 12, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5012700455523005
# Best Params: {'C': 0.4977711317588015, 'max_iter': 8695, 'tol': 0.009861321981421874, 'n_iter_no_change': 6, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5038771463527824
# Best Params: {'C': 0.36998780473090553, 'max_iter': 6559, 'tol': 0.00081965070331883, 'n_iter_no_change': 15, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5023837297763352
# Best Params: {'C': 0.4436880151200362, 'max_iter': 7099, 'tol': 7.773962458460971e-05, 'n_iter_no_change': 12, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5044106428622607
# Best Params: {'C': 0.3368129026529419, 'max_iter': 9849, 'tol': 7.477110989549909e-05, 'n_iter_no_change': 9, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4926850111092122
# Best Params: {'C': 0.8890776113565728, 'max_iter': 8324, 'tol': 0.02954103131578134, 'n_iter_no_change': 13, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49752525767935507
# Best Params: {'C': 0.6858542373817552, 'max_iter': 1443, 'tol': 0.0004900458963327223, 'n_iter_no_change': 6, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5008513558159039
# Best Params: {'C': 0.5212879112787739, 'max_iter': 5901, 'tol': 0.024041103598860258, 'n_iter_no_change': 12, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49879409616658454
# Best Params: {'C': 0.6405894974737697, 'max_iter': 9655, 'tol': 6.775059272354807e-05, 'n_iter_no_change': 15, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49988761328792636
# Best Params: {'C': 0.5763932967733567, 'max_iter': 5514, 'tol': 0.0006237127060241108, 'n_iter_no_change': 13, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5016521757525756
# Best Params: {'C': 0.4810876817916582, 'max_iter': 7098, 'tol': 0.0009067427611339255, 'n_iter_no_change': 9, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4915950211728474
# Best Params: {'C': 0.9469358247125255, 'max_iter': 8535, 'tol': 0.006416166808091206, 'n_iter_no_change': 6, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5022929866309369
# Best Params: {'C': 0.4490870840797637, 'max_iter': 8228, 'tol': 0.07638127367340808, 'n_iter_no_change': 11, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5040142353556308
# Best Params: {'C': 0.35645376605303813, 'max_iter': 5703, 'tol': 1.1151029073697643e-05, 'n_iter_no_change': 9, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49380608037154977
# Best Params: {'C': 0.8439794156762803, 'max_iter': 3580, 'tol': 0.003248474140224121, 'n_iter_no_change': 5, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49929772599007916
# Best Params: {'C': 0.6053710641610899, 'max_iter': 4308, 'tol': 0.0004074122747747537, 'n_iter_no_change': 12, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49237331236296966
# Best Params: {'C': 0.9038252119875079, 'max_iter': 2453, 'tol': 0.0003922566562242395, 'n_iter_no_change': 13, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5024805821550216
# Best Params: {'C': 0.4360035656026161, 'max_iter': 1854, 'tol': 0.0007755328255108114, 'n_iter_no_change': 12, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5025897979704095
# Best Params: {'C': 0.4236243117512807, 'max_iter': 9209, 'tol': 5.100825156444694e-05, 'n_iter_no_change': 10, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4998218617986869
# Best Params: {'C': 0.5809500456881576, 'max_iter': 1596, 'tol': 2.2915020073986815e-05, 'n_iter_no_change': 10, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5024742538149147
# Best Params: {'C': 0.43648114476426403, 'max_iter': 5141, 'tol': 0.00021744408144026248, 'n_iter_no_change': 6, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5038771463527824
# Best Params: {'C': 0.36971353814062746, 'max_iter': 1156, 'tol': 0.09548875260005339, 'n_iter_no_change': 12, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5036690705162017
# Best Params: {'C': 0.38192311253316946, 'max_iter': 6715, 'tol': 0.0008179145194861404, 'n_iter_no_change': 6, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49447797803135324
# Best Params: {'C': 0.8125786777278965, 'max_iter': 8699, 'tol': 0.0005303971721432919, 'n_iter_no_change': 5, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49690661991847435
# Best Params: {'C': 0.7151658914447716, 'max_iter': 6486, 'tol': 0.00020351551062926506, 'n_iter_no_change': 6, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5018797230950095
# Best Params: {'C': 0.4707616508543766, 'max_iter': 3434, 'tol': 8.069875722045785e-05, 'n_iter_no_change': 5, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4912719058050383
# Best Params: {'C': 0.963285881566402, 'max_iter': 1083, 'tol': 0.0006831263941032681, 'n_iter_no_change': 7, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49099187771206537
# Best Params: {'C': 0.9775481291705359, 'max_iter': 7922, 'tol': 0.0019020675748439597, 'n_iter_no_change': 8, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5028891967695063
# Best Params: {'C': 0.4111723211948014, 'max_iter': 9011, 'tol': 4.47580750969761e-06, 'n_iter_no_change': 11, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5040331591885613
# Best Params: {'C': 0.3558354980255078, 'max_iter': 9681, 'tol': 0.0005749718708740933, 'n_iter_no_change': 6, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49094636292438265
# Best Params: {'C': 0.9819037497544272, 'max_iter': 1491, 'tol': 0.032143831895565314, 'n_iter_no_change': 6, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4956711432272139
# Best Params: {'C': 0.7636328750916066, 'max_iter': 8403, 'tol': 3.988727370277808e-05, 'n_iter_no_change': 14, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4906361429898422
# Best Params: {'C': 0.9944981325469122, 'max_iter': 4163, 'tol': 0.005483481076956299, 'n_iter_no_change': 8, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.50368801269284
# Best Params: {'C': 0.3814430958747845, 'max_iter': 9602, 'tol': 0.028239068055155272, 'n_iter_no_change': 10, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5000805624104273
# Best Params: {'C': 0.564914042599618, 'max_iter': 7207, 'tol': 0.04413540427760248, 'n_iter_no_change': 14, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49486593436583204
# Best Params: {'C': 0.798465894410918, 'max_iter': 5710, 'tol': 8.977634549320901e-05, 'n_iter_no_change': 12, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.499450551781782
# Best Params: {'C': 0.5972031582664896, 'max_iter': 6344, 'tol': 4.38022413772146e-05, 'n_iter_no_change': 12, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4992786217431893
# Best Params: {'C': 0.6072296866843537, 'max_iter': 9298, 'tol': 0.07074010355709233, 'n_iter_no_change': 5, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4988112422518468
# Best Params: {'C': 0.6354593127531774, 'max_iter': 1001, 'tol': 1.741569488945885e-05, 'n_iter_no_change': 13, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4934174285482473
# Best Params: {'C': 0.8617019352220328, 'max_iter': 7362, 'tol': 0.00038849876008751125, 'n_iter_no_change': 15, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4920976243710376
# Best Params: {'C': 0.9184625726996924, 'max_iter': 3573, 'tol': 0.00872326825773592, 'n_iter_no_change': 8, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5035219440962594
# Best Params: {'C': 0.39008648928498785, 'max_iter': 7300, 'tol': 0.0680990069070394, 'n_iter_no_change': 9, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49851740456588417
# Best Params: {'C': 0.6581030503330876, 'max_iter': 1000, 'tol': 0.04460112666394448, 'n_iter_no_change': 15, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5038462187283862
# Best Params: {'C': 0.36330570342790874, 'max_iter': 3947, 'tol': 0.00476128749978938, 'n_iter_no_change': 5, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5030906941395035
# Best Params: {'C': 0.3966371938494062, 'max_iter': 1499, 'tol': 0.009498189321734053, 'n_iter_no_change': 15, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5040814949740268
# Best Params: {'C': 0.3526521336323247, 'max_iter': 3015, 'tol': 0.0003262362046800769, 'n_iter_no_change': 13, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5016458363302504
# Best Params: {'C': 0.4811472384800842, 'max_iter': 8874, 'tol': 0.008605224228720308, 'n_iter_no_change': 9, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49496017601009673
# Best Params: {'C': 0.7942251907988552, 'max_iter': 5182, 'tol': 0.012340849110439518, 'n_iter_no_change': 10, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4998218617986869
# Best Params: {'C': 0.5808179065623185, 'max_iter': 7546, 'tol': 8.044660518475572e-05, 'n_iter_no_change': 14, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49324335867429747
# Best Params: {'C': 0.868990938362034, 'max_iter': 3896, 'tol': 0.0006675190099065551, 'n_iter_no_change': 11, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49415017536673406
# Best Params: {'C': 0.8249708751811162, 'max_iter': 1466, 'tol': 9.885272465792023e-05, 'n_iter_no_change': 9, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5003179448047819
# Best Params: {'C': 0.5576589021707017, 'max_iter': 2967, 'tol': 9.667784693551137e-05, 'n_iter_no_change': 10, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4944612930332152
# Best Params: {'C': 0.8119801627849954, 'max_iter': 3769, 'tol': 0.0007671413720923841, 'n_iter_no_change': 14, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5007878818685507
# Best Params: {'C': 0.5271450368474306, 'max_iter': 4700, 'tol': 0.009706782540340728, 'n_iter_no_change': 6, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4945897185459416
# Best Params: {'C': 0.8063811397584444, 'max_iter': 6229, 'tol': 0.08718149818743715, 'n_iter_no_change': 9, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4969452528037303
# Best Params: {'C': 0.7088216577783846, 'max_iter': 3586, 'tol': 4.460179633432518e-05, 'n_iter_no_change': 7, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49650498497271245
# Best Params: {'C': 0.7343314463577069, 'max_iter': 9312, 'tol': 0.05001505808681385, 'n_iter_no_change': 12, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49906200925257843
# Best Params: {'C': 0.617541152127866, 'max_iter': 7331, 'tol': 0.00020386585386161205, 'n_iter_no_change': 12, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4905198357827503
# Best Params: {'C': 0.9997876453981251, 'max_iter': 9626, 'tol': 0.0327987867481896, 'n_iter_no_change': 11, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49212591693312585
# Best Params: {'C': 0.9164597177974525, 'max_iter': 7799, 'tol': 0.09100333387513242, 'n_iter_no_change': 13, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5035554073842752
# Best Params: {'C': 0.38567300967593554, 'max_iter': 3412, 'tol': 8.764545112167834e-05, 'n_iter_no_change': 15, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5018797230950095
# Best Params: {'C': 0.4707539891367952, 'max_iter': 8785, 'tol': 0.00040930657875120664, 'n_iter_no_change': 7, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5044250025285729
# Best Params: {'C': 0.33368536520366265, 'max_iter': 4455, 'tol': 0.004871903167837467, 'n_iter_no_change': 7, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4943259385665529
# Best Params: {'C': 0.8172874978469176, 'max_iter': 1506, 'tol': 0.0008686769805541111, 'n_iter_no_change': 13, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5013881835110886
# Best Params: {'C': 0.48972755330752726, 'max_iter': 6570, 'tol': 0.007150387200661473, 'n_iter_no_change': 12, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4924163101684268
# Best Params: {'C': 0.9014283509219918, 'max_iter': 7781, 'tol': 0.09791738281780238, 'n_iter_no_change': 10, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49155630838722925
# Best Params: {'C': 0.9499621289188818, 'max_iter': 9148, 'tol': 5.922020332793158e-05, 'n_iter_no_change': 15, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4994887503871497
# Best Params: {'C': 0.5959623789350386, 'max_iter': 5837, 'tol': 0.009015569674300703, 'n_iter_no_change': 6, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49430666774745413
# Best Params: {'C': 0.8190655030306568, 'max_iter': 4385, 'tol': 0.06392955294079204, 'n_iter_no_change': 14, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49257105253037176
# Best Params: {'C': 0.8945510147518982, 'max_iter': 9572, 'tol': 0.017729473698381994, 'n_iter_no_change': 5, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49523679622865086
# Best Params: {'C': 0.7807733984448212, 'max_iter': 2686, 'tol': 2.641591331503153e-05, 'n_iter_no_change': 12, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49867495668127615
# Best Params: {'C': 0.649368738708864, 'max_iter': 9993, 'tol': 0.08847957348530258, 'n_iter_no_change': 7, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5014071870225616
# Best Params: {'C': 0.4885308462898488, 'max_iter': 9763, 'tol': 0.00037404354231475664, 'n_iter_no_change': 8, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5008259841919334
# Best Params: {'C': 0.5242351506026006, 'max_iter': 6823, 'tol': 0.0650502408731388, 'n_iter_no_change': 7, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5025329451878267
# Best Params: {'C': 0.4319248296795549, 'max_iter': 6355, 'tol': 0.0757368732497147, 'n_iter_no_change': 13, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5012700455523005
# Best Params: {'C': 0.49842248207861395, 'max_iter': 5690, 'tol': 0.003647368296834768, 'n_iter_no_change': 5, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4977298620912476
# Best Params: {'C': 0.6777055138118879, 'max_iter': 1752, 'tol': 0.06900985826459591, 'n_iter_no_change': 7, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49376750221979376
# Best Params: {'C': 0.8450386929968408, 'max_iter': 1298, 'tol': 0.0005761719798307368, 'n_iter_no_change': 12, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5037869677675245
# Best Params: {'C': 0.37747262723288205, 'max_iter': 5221, 'tol': 0.011350587165727056, 'n_iter_no_change': 9, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4976723423251068
# Best Params: {'C': 0.6798822277463749, 'max_iter': 2583, 'tol': 0.000991848599460471, 'n_iter_no_change': 13, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49701146491396
# Best Params: {'C': 0.7067652424244051, 'max_iter': 6176, 'tol': 0.0020636148126392064, 'n_iter_no_change': 10, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5026382827715276
# Best Params: {'C': 0.420958458425458, 'max_iter': 1579, 'tol': 0.006559470486585899, 'n_iter_no_change': 11, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5022931417098172
# Best Params: {'C': 0.4516909399945376, 'max_iter': 1011, 'tol': 0.06426728912978648, 'n_iter_no_change': 5, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49717792872302863
# Best Params: {'C': 0.6994441234259158, 'max_iter': 2352, 'tol': 0.0008552952253564282, 'n_iter_no_change': 15, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49702440456187064
# Best Params: {'C': 0.7042429983355047, 'max_iter': 5556, 'tol': 0.0787453237955633, 'n_iter_no_change': 14, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5043349982086786
# Best Params: {'C': 0.3412572363419464, 'max_iter': 8451, 'tol': 0.09425816384412515, 'n_iter_no_change': 10, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4938902854899082
# Best Params: {'C': 0.8393193087898765, 'max_iter': 9460, 'tol': 9.152872934837975e-05, 'n_iter_no_change': 11, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4998409500583183
# Best Params: {'C': 0.5798030109893046, 'max_iter': 2351, 'tol': 0.0002747982889441941, 'n_iter_no_change': 9, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49260549086636046
# Best Params: {'C': 0.8932992041221175, 'max_iter': 6264, 'tol': 0.0009202256437095839, 'n_iter_no_change': 11, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4910609600588804
# Best Params: {'C': 0.9726076539989248, 'max_iter': 9940, 'tol': 0.0007994746199292181, 'n_iter_no_change': 13, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49523906946611085
# Best Params: {'C': 0.7787488677552169, 'max_iter': 1211, 'tol': 0.07654408510401585, 'n_iter_no_change': 14, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5029208148714461
# Best Params: {'C': 0.41024409984283816, 'max_iter': 3821, 'tol': 0.08413420652636973, 'n_iter_no_change': 12, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.501405065005417
# Best Params: {'C': 0.48834561305726376, 'max_iter': 6879, 'tol': 0.07184863975708955, 'n_iter_no_change': 6, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49962456889054807
# Best Params: {'C': 0.5924129940260476, 'max_iter': 2761, 'tol': 0.0005695803913708081, 'n_iter_no_change': 6, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49740377377747724
# Best Params: {'C': 0.6898885640013952, 'max_iter': 2672, 'tol': 0.0019987337720422317, 'n_iter_no_change': 12, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4943965940164924
# Best Params: {'C': 0.8155948855024069, 'max_iter': 3488, 'tol': 8.712166392305154e-05, 'n_iter_no_change': 13, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5021117203651014
# Best Params: {'C': 0.46065702199781566, 'max_iter': 6588, 'tol': 0.034258555000056826, 'n_iter_no_change': 8, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5019050639602495
# Best Params: {'C': 0.4692640151054646, 'max_iter': 4001, 'tol': 9.257335037582327e-05, 'n_iter_no_change': 7, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49749970234551727
# Best Params: {'C': 0.6871379876306279, 'max_iter': 4703, 'tol': 5.6961824877081597e-05, 'n_iter_no_change': 7, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.493773932048989
# Best Params: {'C': 0.8448266750835378, 'max_iter': 9323, 'tol': 0.0849029396625867, 'n_iter_no_change': 14, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49407306894697767
# Best Params: {'C': 0.8272909286023538, 'max_iter': 3438, 'tol': 0.004578359049369864, 'n_iter_no_change': 7, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5022445787716109
# Best Params: {'C': 0.4546835130552299, 'max_iter': 1951, 'tol': 8.139844764570912e-05, 'n_iter_no_change': 11, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49415017536673406
# Best Params: {'C': 0.8249817912282151, 'max_iter': 4404, 'tol': 0.003164659721274413, 'n_iter_no_change': 5, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5007457753521246
# Best Params: {'C': 0.5360767694446825, 'max_iter': 9891, 'tol': 0.0008008840137841217, 'n_iter_no_change': 10, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5015507910515337
# Best Params: {'C': 0.4846778198658358, 'max_iter': 7662, 'tol': 0.0691148615618477, 'n_iter_no_change': 9, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5053283088777077
# Best Params: {'C': 0.3114932360232036, 'max_iter': 8476, 'tol': 0.08916583121537638, 'n_iter_no_change': 8, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.491302227280117
# Best Params: {'C': 0.9615760734002823, 'max_iter': 2016, 'tol': 0.0007443502928648856, 'n_iter_no_change': 6, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5028891967695063
# Best Params: {'C': 0.41110791376876477, 'max_iter': 2220, 'tol': 0.0006799361614050047, 'n_iter_no_change': 14, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5000424023473939
# Best Params: {'C': 0.5667186738633521, 'max_iter': 7008, 'tol': 0.020987907804110056, 'n_iter_no_change': 8, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4969194111139477
# Best Params: {'C': 0.713862971447943, 'max_iter': 7310, 'tol': 9.688186493582772e-05, 'n_iter_no_change': 13, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5020084736445974
# Best Params: {'C': 0.4647488201381399, 'max_iter': 6906, 'tol': 0.00015579727523366374, 'n_iter_no_change': 6, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.501238320625553
# Best Params: {'C': 0.500013541864024, 'max_iter': 2384, 'tol': 0.0026356090222039636, 'n_iter_no_change': 6, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5013798591358526
# Best Params: {'C': 0.49152106064545437, 'max_iter': 2012, 'tol': 0.004817808594105133, 'n_iter_no_change': 8, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4936474325039703
# Best Params: {'C': 0.8508784769661131, 'max_iter': 6134, 'tol': 0.0007304901458359436, 'n_iter_no_change': 14, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49631275972477695
# Best Params: {'C': 0.7410481099203472, 'max_iter': 9797, 'tol': 3.1228284957039274e-05, 'n_iter_no_change': 14, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5023121338416928
# Best Params: {'C': 0.4504229551238599, 'max_iter': 6245, 'tol': 0.06800203728798007, 'n_iter_no_change': 15, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5025834716958812
# Best Params: {'C': 0.42421449079350126, 'max_iter': 8425, 'tol': 0.07659275534226306, 'n_iter_no_change': 5, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49956515652244
# Best Params: {'C': 0.5945844619857072, 'max_iter': 1551, 'tol': 0.09905097486360454, 'n_iter_no_change': 6, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5028639013263496
# Best Params: {'C': 0.411794314993292, 'max_iter': 9998, 'tol': 0.041572969008755005, 'n_iter_no_change': 9, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5005827629320393
# Best Params: {'C': 0.5442772725162623, 'max_iter': 8917, 'tol': 4.51809528872888e-05, 'n_iter_no_change': 11, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5041398266500287
# Best Params: {'C': 0.3493567446337939, 'max_iter': 8039, 'tol': 0.007201419993729097, 'n_iter_no_change': 7, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5043791251865026
# Best Params: {'C': 0.339233340298941, 'max_iter': 3655, 'tol': 0.007563807359750963, 'n_iter_no_change': 14, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49879409616658454
# ...
# F1 Accuracy: 0.4917175985526648
# Best Params: {'C': 0.9411049645248817, 'max_iter': 2489, 'tol': 0.0004701835195147796, 'n_iter_no_change': 6, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4939976528326043
# Best Params: {'C': 0.8315612552525657, 'max_iter': 4519, 'tol': 0.07526788729862809, 'n_iter_no_change': 10, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.491325943450713
# Best Params: {'C': 0.9600335979200287, 'max_iter': 3190, 'tol': 0.004879996354462178, 'n_iter_no_change': 5, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49386878822670766
# Best Params: {'C': 0.8405604455054525, 'max_iter': 3705, 'tol': 0.008522911492138265, 'n_iter_no_change': 15, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5010396859343833
# Best Params: {'C': 0.5113245571596077, 'max_iter': 9820, 'tol': 0.07424441984166538, 'n_iter_no_change': 6, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5046473805290346
# Best Params: {'C': 0.3254731707553688, 'max_iter': 2205, 'tol': 0.0023202619865701993, 'n_iter_no_change': 12, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4923388596120066
# Best Params: {'C': 0.905814131726763, 'max_iter': 8573, 'tol': 4.659974618936571e-05, 'n_iter_no_change': 11, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4961911047712321
# Best Params: {'C': 0.7435405480133235, 'max_iter': 1106, 'tol': 6.404303504700818e-05, 'n_iter_no_change': 12, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5027541692715813
# Best Params: {'C': 0.4168238805977959, 'max_iter': 3852, 'tol': 0.041346419230225646, 'n_iter_no_change': 11, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49854941955543847
# Best Params: {'C': 0.6560031983847757, 'max_iter': 3315, 'tol': 0.0548289070642764, 'n_iter_no_change': 11, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4989897274811104
# Best Params: {'C': 0.622626066578451, 'max_iter': 3986, 'tol': 0.0008987498577906511, 'n_iter_no_change': 8, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5017743770646432
# Best Params: {'C': 0.4763904712881557, 'max_iter': 8756, 'tol': 0.00048618225903379397, 'n_iter_no_change': 7, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5016880886098443
# Best Params: {'C': 0.4797735799644798, 'max_iter': 2921, 'tol': 0.00040185850737588263, 'n_iter_no_change': 12, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5043098542868825
# Best Params: {'C': 0.3435588622004713, 'max_iter': 7166, 'tol': 0.044013515001764654, 'n_iter_no_change': 12, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5022551560009976
# Best Params: {'C': 0.4535819505410259, 'max_iter': 2908, 'tol': 8.721888464887052e-05, 'n_iter_no_change': 10, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5019240690465921
# Best Params: {'C': 0.4685862187782674, 'max_iter': 3599, 'tol': 0.04139135487584472, 'n_iter_no_change': 13, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49094636292438265
# Best Params: {'C': 0.9806882899097666, 'max_iter': 6453, 'tol': 1.938855048910824e-05, 'n_iter_no_change': 15, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5037512131313556
# Best Params: {'C': 0.37863638332328864, 'max_iter': 6287, 'tol': 0.00029487037016561016, 'n_iter_no_change': 8, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49803231591741676
# Best Params: {'C': 0.6690247941048793, 'max_iter': 7343, 'tol': 0.03513433529012952, 'n_iter_no_change': 6, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4988282444044425
# Best Params: {'C': 0.6335883502922415, 'max_iter': 3440, 'tol': 0.08752040870314133, 'n_iter_no_change': 8, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5031159750721995
# Best Params: {'C': 0.3944865325118632, 'max_iter': 9800, 'tol': 0.013838187737976489, 'n_iter_no_change': 8, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49854941955543847
# Best Params: {'C': 0.6561185994367722, 'max_iter': 6115, 'tol': 2.4436414368649278e-05, 'n_iter_no_change': 10, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4938902854899082
# Best Params: {'C': 0.8391292564645683, 'max_iter': 1990, 'tol': 0.00912018225596957, 'n_iter_no_change': 15, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4952346853528379
# Best Params: {'C': 0.780470965932027, 'max_iter': 4512, 'tol': 5.8406525998688e-05, 'n_iter_no_change': 5, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49427876615896577
# Best Params: {'C': 0.8200951668834271, 'max_iter': 8070, 'tol': 0.008058995987710477, 'n_iter_no_change': 11, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5053974402155608
# Best Params: {'C': 0.30956643586384774, 'max_iter': 7212, 'tol': 9.744653222639212e-05, 'n_iter_no_change': 14, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4925150532258134
# Best Params: {'C': 0.8976932143009966, 'max_iter': 4225, 'tol': 7.021117980111872e-05, 'n_iter_no_change': 14, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4910306225501104
# Best Params: {'C': 0.9750571565566417, 'max_iter': 4338, 'tol': 5.411920102436966e-05, 'n_iter_no_change': 10, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49182963910141
# Best Params: {'C': 0.9365514911183652, 'max_iter': 2683, 'tol': 0.06211198325484699, 'n_iter_no_change': 15, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4919705158024354
# Best Params: {'C': 0.9266505149423834, 'max_iter': 4277, 'tol': 0.05888407381527751, 'n_iter_no_change': 9, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5038603359968948
# Best Params: {'C': 0.37199548274281174, 'max_iter': 8473, 'tol': 8.164341586461662e-05, 'n_iter_no_change': 12, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5038309649981436
# Best Params: {'C': 0.37426564169538146, 'max_iter': 2864, 'tol': 5.611815841126366e-05, 'n_iter_no_change': 14, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4914853297857323
# Best Params: {'C': 0.9531031004323898, 'max_iter': 8322, 'tol': 0.0005520521713030233, 'n_iter_no_change': 6, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5020338094392437
# Best Params: {'C': 0.463876244107437, 'max_iter': 4754, 'tol': 0.0008957249552063371, 'n_iter_no_change': 14, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5028891967695063
# Best Params: {'C': 0.4111303240760824, 'max_iter': 4552, 'tol': 0.026915186511451257, 'n_iter_no_change': 15, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4921105168883246
# Best Params: {'C': 0.9175299275121693, 'max_iter': 3826, 'tol': 7.936482041046656e-07, 'n_iter_no_change': 12, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4986942176134119
# Best Params: {'C': 0.6449958980383944, 'max_iter': 4557, 'tol': 0.0002352442212025133, 'n_iter_no_change': 12, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49064260397582315
# Best Params: {'C': 0.9942078532521452, 'max_iter': 6785, 'tol': 0.0010893187485736641, 'n_iter_no_change': 5, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5043791251865026
# Best Params: {'C': 0.3392305226991083, 'max_iter': 2834, 'tol': 0.0009326921337072893, 'n_iter_no_change': 15, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5020528107228177
# Best Params: {'C': 0.463665951968696, 'max_iter': 6429, 'tol': 0.00026223740712671213, 'n_iter_no_change': 7, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5011431765064527
# Best Params: {'C': 0.5061628126186998, 'max_iter': 4693, 'tol': 0.015003536734621329, 'n_iter_no_change': 10, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5008767545680183
# Best Params: {'C': 0.519661231782685, 'max_iter': 8323, 'tol': 0.0003715257548111986, 'n_iter_no_change': 8, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5038315388151541
# Best Params: {'C': 0.36341517926961164, 'max_iter': 5479, 'tol': 0.0006391941445084413, 'n_iter_no_change': 7, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4991151343849866
# Best Params: {'C': 0.6142845332058368, 'max_iter': 9408, 'tol': 5.6741793177379447e-05, 'n_iter_no_change': 7, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49701146491396
# Best Params: {'C': 0.7071154524102117, 'max_iter': 5443, 'tol': 1.9164739763810974e-05, 'n_iter_no_change': 7, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5011495031521367
# Best Params: {'C': 0.5044489287340648, 'max_iter': 7337, 'tol': 1.3910067729722645e-05, 'n_iter_no_change': 12, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4939719444693391
# Best Params: {'C': 0.8324157303289248, 'max_iter': 2221, 'tol': 0.0016843778852533241, 'n_iter_no_change': 13, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49302873936370156
# Best Params: {'C': 0.8769191298430563, 'max_iter': 6804, 'tol': 0.05725420939758773, 'n_iter_no_change': 13, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5012214070100719
# Best Params: {'C': 0.5010567565872113, 'max_iter': 8518, 'tol': 0.006940931149250177, 'n_iter_no_change': 11, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4982599569132188
# Best Params: {'C': 0.6638076817807845, 'max_iter': 3517, 'tol': 0.07120809808501301, 'n_iter_no_change': 6, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4918360888493547
# Best Params: {'C': 0.9353291975295788, 'max_iter': 2502, 'tol': 0.04821080119259964, 'n_iter_no_change': 9, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5013186803882805
# Best Params: {'C': 0.4958785592825361, 'max_iter': 4296, 'tol': 7.749761395512341e-05, 'n_iter_no_change': 10, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4961975081542799
# Best Params: {'C': 0.743417368984435, 'max_iter': 8797, 'tol': 7.226774403782754e-06, 'n_iter_no_change': 11, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49476525751521383
# Best Params: {'C': 0.8016494174067506, 'max_iter': 4235, 'tol': 3.2612162353599625e-05, 'n_iter_no_change': 5, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4990641433197659
# Best Params: {'C': 0.6165532051369754, 'max_iter': 5523, 'tol': 0.0699506814235727, 'n_iter_no_change': 6, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4936431090277244
# Best Params: {'C': 0.8521198980182405, 'max_iter': 2628, 'tol': 0.03231974825586615, 'n_iter_no_change': 5, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4918349632049533
# Best Params: {'C': 0.9320796042206998, 'max_iter': 3359, 'tol': 4.686605066954983e-05, 'n_iter_no_change': 10, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49108678722111443
# Best Params: {'C': 0.9699095762028382, 'max_iter': 3506, 'tol': 0.0008742518464388, 'n_iter_no_change': 13, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.504659981461195
# Best Params: {'C': 0.325309716774045, 'max_iter': 6655, 'tol': 0.01520882760382133, 'n_iter_no_change': 13, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4956989659623964
# Best Params: {'C': 0.7618645066071639, 'max_iter': 7663, 'tol': 0.003914538845973113, 'n_iter_no_change': 12, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4925366118397156
# Best Params: {'C': 0.8963782794238475, 'max_iter': 1668, 'tol': 0.09620907383402429, 'n_iter_no_change': 5, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5027225453792765
# Best Params: {'C': 0.4193038497170806, 'max_iter': 2830, 'tol': 0.0009484252350162474, 'n_iter_no_change': 13, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5048485614389822
# Best Params: {'C': 0.32159249091542774, 'max_iter': 3783, 'tol': 2.7409140087618966e-05, 'n_iter_no_change': 14, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49447155581339797
# Best Params: {'C': 0.8128935431156914, 'max_iter': 2632, 'tol': 0.078589821102302, 'n_iter_no_change': 10, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5008069332723368
# Best Params: {'C': 0.525757871636975, 'max_iter': 5427, 'tol': 0.005418050606296807, 'n_iter_no_change': 15, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49257315739094765
# Best Params: {'C': 0.8951517181581878, 'max_iter': 5305, 'tol': 0.02407675304418867, 'n_iter_no_change': 10, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5026298335072473
# Best Params: {'C': 0.422071225330699, 'max_iter': 1853, 'tol': 0.0439271813713026, 'n_iter_no_change': 5, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5001293167412182
# Best Params: {'C': 0.5629865496938379, 'max_iter': 5346, 'tol': 0.0007666971043566932, 'n_iter_no_change': 10, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5017113218004206
# Best Params: {'C': 0.4793267537549464, 'max_iter': 1082, 'tol': 0.0009423462632043265, 'n_iter_no_change': 10, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4916014731105988
# Best Params: {'C': 0.9463432951776094, 'max_iter': 8840, 'tol': 0.006776253038560975, 'n_iter_no_change': 11, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49461329147936167
# Best Params: {'C': 0.8051769295565128, 'max_iter': 8928, 'tol': 0.08604088033575583, 'n_iter_no_change': 9, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5048275397239961
# Best Params: {'C': 0.32246376809580396, 'max_iter': 4985, 'tol': 0.00042227435945074314, 'n_iter_no_change': 8, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5021706874759576
# Best Params: {'C': 0.4574663000462989, 'max_iter': 2861, 'tol': 0.0007465366893472842, 'n_iter_no_change': 11, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49762763171320695
# Best Params: {'C': 0.6815501185398173, 'max_iter': 9021, 'tol': 0.006782131441340439, 'n_iter_no_change': 9, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5005764079612112
# Best Params: {'C': 0.5449859783835234, 'max_iter': 2217, 'tol': 0.0005478093436623605, 'n_iter_no_change': 10, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5003666761338347
# Best Params: {'C': 0.5540489271088562, 'max_iter': 6357, 'tol': 0.00352502712771522, 'n_iter_no_change': 15, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5029752477965429
# Best Params: {'C': 0.4041967247145109, 'max_iter': 1784, 'tol': 5.924882931348981e-05, 'n_iter_no_change': 10, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5043245157048202
# Best Params: {'C': 0.34266353418180545, 'max_iter': 8526, 'tol': 3.581637274231761e-05, 'n_iter_no_change': 7, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.49863870164842405
# Best Params: {'C': 0.6531289938048381, 'max_iter': 9706, 'tol': 4.878722312147612e-05, 'n_iter_no_change': 6, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4936474325039703
# Best Params: {'C': 0.8516990801455719, 'max_iter': 8060, 'tol': 0.008657417559528443, 'n_iter_no_change': 10, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4939590899585608
# Best Params: {'C': 0.8330024283143029, 'max_iter': 9748, 'tol': 7.552418536572237e-05, 'n_iter_no_change': 10, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5010987708163085
# Best Params: {'C': 0.5079658844649458, 'max_iter': 6980, 'tol': 0.0007271231420282225, 'n_iter_no_change': 5, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4973441015237926
# Best Params: {'C': 0.6916422614529433, 'max_iter': 7986, 'tol': 3.915813432433897e-05, 'n_iter_no_change': 8, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4987772569798248
# Best Params: {'C': 0.6388875971039858, 'max_iter': 4068, 'tol': 2.3747171446851397e-05, 'n_iter_no_change': 15, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.5029524316379025
# Best Params: {'C': 0.41006329133915065, 'max_iter': 8114, 'tol': 0.06426995259485971, 'n_iter_no_change': 6, 'shuffle': False, 'loss': 'squared_hinge'}
# F1 Accuracy: 0.4969194111139477
# Best Params: {'C': 0.7141518236810567, 'max_iter': 9427, 'tol': 2.8297024276228712e-05, 'n_iter_no_change': 12, 'shuffle': False, 'loss': 'squared_hinge'}

# %% [markdown]
# ### Resultados

# %% [markdown]
# F1 Accuracy: 0.5037195819215238
#
# Best Params: {'C': 0.37986432749857796, 'max_iter': 6855, 'tol': 0.007251420064349369, 'n_iter_no_change': 8, 'shuffle': False, 'loss': 'squared_hinge'}
#
#
# ---
#
# F1 Accuracy: 0.5044168717758521
#
# Best Params: {'C': 0.3358956626879644, 'max_iter': 4684, 'tol': 0.009943273587276515, 'n_iter_no_change': 11, 'shuffle': False, 'loss': 'squared_hinge'}

# %% [markdown]
# ### Kaggle submission

# %%
from sklearn.linear_model import PassiveAggressiveClassifier

# Define hyperparameters
n_batches = 6 # ~?M batch size
n_max_iter = 10000
cut_score = 0.48

# Split the data into features (X) and target variable (y)
X_train = train_df.drop('label', axis=1)
y_train = train_df['label']

X_batch_size = int(np.floor(X_train.shape[0]/n_batches))
y_batch_size = int(np.floor(y_train.shape[0]/n_batches))

X_test = val_df.drop('label', axis=1)
y_test = val_df['label']

params =  {'C': 0.37986432749857796,
  'max_iter': 6855,
  'tol': 0.007251420064349369,
  'n_iter_no_change': 8,
  'shuffle': False,
  'loss': 'squared_hinge'
  }

# Instantiate the model
model = PassiveAggressiveClassifier(
              C=params['C'],
              max_iter=params['max_iter'],
              tol=params['tol'],
              n_iter_no_change=params['n_iter_no_change'],
              shuffle=params['shuffle'],
              loss=params['loss'],
              random_state=42
              )

# Train the model in batches, keeping label proportion
for i in range(0, n_batches):
    X_batch = X_train.iloc[i*X_batch_size: (i+1)*X_batch_size]
    gc.collect()

    y_batch = y_train.iloc[i*y_batch_size:i*y_batch_size + y_batch_size]

    model.partial_fit(X_batch, y_batch, classes=[0,1])

# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the model
f1_accuracy = f1_score(y_test, y_pred)

print(f'F1 Accuracy: {f1_accuracy}')
print(f'Best Params: {params}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-0a18c1d38ef3> in <cell line: 23>()
#      21            }
#      22
# ---> 23 rf_model = RandomForestClassifier(
#      24     n_estimators = params['n_estimators'],
#      25     criterion=params['criterion'],
#
# NameError: name 'RandomForestClassifier' is not defined

# %%
test_df = pq.read_table('test_processed.parq').to_pandas()

# %%
# in case I need them again
train_df = pq.read_table('train_encoded.parq').to_pandas()
val_df = pq.read_table('val_encoded.parq').to_pandas()

# %%
train_df.to_parquet('train_encoded.parq')
val_df.to_parquet('val_encoded.parq')
del train_df, val_df
gc.collect()
# Out:
# 0

# %%
kaggle_pred = model.predict(test_df)
kaggle_df = pd.DataFrame({'attacker_ip_enum': test_ips, 'prediction': kaggle_pred})

# %%
kaggle_df = kaggle_df.groupby('attacker_ip_enum').mean().reset_index()
kaggle_df['prediction'] = kaggle_df['prediction'].round().astype(int)

# %%
kaggle_df.set_index('attacker_ip_enum').to_csv('rcv_submission.csv')
